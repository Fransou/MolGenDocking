# %%
# %cd ..
# Out:
# /home/philippe/MolGenDocking
# /home/philippe/miniconda3/envs/MolGen/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
from Bio.PDB import MMCIFParser, PDBIO, PPBuilder
import nglview as nv

# %%
path = "data/sair_data/structures/sample_1006050_model_0.cif"
parser = MMCIFParser()
structure = parser.get_structure('protein_id', path)

view = nv.show_biopython(structure)
view
# Out:
# NGLWidget()

# %%
from mol_gen_docking.data.SAIR_identify_pockets import process_sair_dataset

# %%
import os
dir = "data/sair_data/structures"
paths = [os.path.join(dir, p) for p  in os.listdir(dir)]

# %%
df = process_sair_dataset(paths, padding=10, iou_threshold=0.6)
# Out:
# Processing CIF files: 100%|██████████| 45/45 [00:09<00:00,  4.70it/s]
