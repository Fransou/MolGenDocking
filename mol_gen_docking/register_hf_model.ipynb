# %% [markdown]
# # Register Model

# %%
from mol_gen_docking.models import  DockGenConfig, DockGenModel, DockGenProcessor
from transformers import AutoConfig, AutoModel, AutoModelForCausalLM, AutoProcessor, AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained("Franso/DockGen-Qwen3-0.6B", trust_remote_code=True)

# %%
AutoConfig.register("dockgen", DockGenConfig)
AutoModelForCausalLM.register(DockGenConfig, DockGenModel)
AutoProcessor.register(DockGenConfig, DockGenProcessor)

DockGenConfig.register_for_auto_class()
DockGenModel.register_for_auto_class("AutoModelForCausalLM")
DockGenProcessor.register_for_auto_class("AutoProcessor")

# %%
# qwen_06B = AutoModelForCausalLM.from_pretrained(
#         "Qwen/Qwen3-0.6B"
# )
# dockgen = DockGenModel.from_language_model(qwen_06B)
# dockgen.push_to_hub('DockGen-Qwen3-0.6B', private=True, use_auth_token=True)

# %%
tokenizer.push_to_hub('DockGen-Qwen3-0.6B', private=True, use_auth_token=True)
# Out:
# /home/philippe/miniconda3/envs/MolGen/lib/python3.10/site-packages/transformers/utils/hub.py:907: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# No files have been modified since last commit. Skipping to prevent empty commit.
# CommitInfo(commit_url='https://huggingface.co/Franso/DockGen-Qwen3-0.6B/commit/026d206a2a54b69523bf2f1ce457ec2d353a5321', commit_message='Upload tokenizer', commit_description='', oid='026d206a2a54b69523bf2f1ce457ec2d353a5321', pr_url=None, repo_url=RepoUrl('https://huggingface.co/Franso/DockGen-Qwen3-0.6B', endpoint='https://huggingface.co', repo_type='model', repo_id='Franso/DockGen-Qwen3-0.6B'), pr_revision=None, pr_num=None)

# %%
processor = DockGenProcessor(tokenizer = tokenizer)
processor.save_pretrained("DockGen-Qwen3-0.6B", private=True, use_auth_token=True)
# Out:
# /home/philippe/miniconda3/envs/MolGen/lib/python3.10/site-packages/transformers/processing_utils.py:673: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# ['DockGen-Qwen3-0.6B/processor_config.json']

# %%
processor.push_to_hub('DockGen-Qwen3-0.6B', private=True, use_auth_token=True)
# Out:
# CommitInfo(commit_url='https://huggingface.co/Franso/DockGen-Qwen3-0.6B/commit/fcba605d11dbeb3e8ca2806175d033442fce570a', commit_message='Upload processor', commit_description='', oid='fcba605d11dbeb3e8ca2806175d033442fce570a', pr_url=None, repo_url=RepoUrl('https://huggingface.co/Franso/DockGen-Qwen3-0.6B', endpoint='https://huggingface.co', repo_type='model', repo_id='Franso/DockGen-Qwen3-0.6B'), pr_revision=None, pr_num=None)

# %%
from transformers import AutoProcessor, AutoModelForCausalLM, AutoTokenizer

# %%
# dockgen = AutoModelForCausalLM.from_pretrained(
#     "Franso/DockGen-Qwen3-0.6B",
#     trust_remote_code=True,
# )
# tokenizer = AutoTokenizer.from_pretrained("Franso/DockGen-Qwen3-0.6B", trust_remote_code=True)
processor = AutoProcessor.from_pretrained("Franso/DockGen-Qwen3-0.6B", trust_remote_code=True)
# Out:
# processor_config.json:   0%|          | 0.00/158 [00:00<?, ?B/s]
# processing_dockgen.py:   0%|          | 0.00/18.7k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/Franso/DockGen-Qwen3-0.6B:
# - processing_dockgen.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# tokenizer_config.json:   0%|          | 0.00/5.53k [00:00<?, ?B/s]

# %%
type(processor)
# Out:
# transformers_modules.Franso.DockGen-Qwen3-0.6B.026d206a2a54b69523bf2f1ce457ec2d353a5321.processing_dockgen.DockGenProcessor
