# %%
# %load_ext autoreload
# %autoreload 2
# %cd ..
# Out:
# /home/philippe/MolGenDocking
# /home/philippe/miniconda3/envs/MolGen/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
from mol_gen_docking.data.prompt_generator import PromptGenerator
from mol_gen_docking.data.pydantic_dataset import read_jsonl, write_jsonl
from tqdm.auto import tqdm
from pathlib import Path

# %% [markdown]
# ## Creating a system prompt

# %%
SYSTEM_PROMT = """You are a molecular modeling assistant. You answer to questions asked by a user in english.
You can first draft your thinking process or inner molologue before arriving to an answer.
You must provide your final answer enclosed in <answer> </answer> tags e.g <answer> answer here </answer>.
"""

SYSTEM_PROMT
# Out:
# 'You are a molecular modeling assistant. You answer to questions asked by a user in english.\nYou can first draft your thinking process or inner molologue before arriving to an answer.\nYou must provide your final answer enclosed in <answer> </answer> tags e.g <answer> answer here </answer>.\n'

# %% [markdown]
# # Molecular Property - Prompt Generation

# %% [markdown]
# ## Creating a jinja template

# %%
from jinja2 import Template
MOLPROP_DATA_PATH = Path("data/polaris")

TO_SHORTNAME = {
    ### ASAP Discovery Antiviral Potency
    "asap-discovery/antiviral-potency-2025-unblinded/pIC50 (SARS-CoV-2 Mpro)": "SARS-CoV-2 main protease inhibition potency (pIC50)",
    "asap-discovery/antiviral-potency-2025-unblinded/pIC50 (MERS-CoV Mpro)": "MERS-CoV main protease inhibition potency (pIC50)",
    ### Polaris ADME
    "polaris/az-logd-74-v1/LOGD_74": "octan-1-ol/water (pH7.4) distribution coefficent",
    "polaris/az-ppb-clearance-v1/log_unbound_PPB": "plasma protein binding (log-percent unbound to plasma protein)",
    "novartis/novartis-cyp3a4-v1/log_kobs": "log-inactivation rate constant of CYP3A4",
    "polaris/drewry2017-pkis2-subset-v2/CLS_EGFR": "inhibation of EGFR kinase",
    "polaris/drewry2017-pkis2-subset-v2/CLS_KIT": "inhibation of KIT kinase",
    "polaris/drewry2017-pkis2-subset-v2/CLS_RET": "inhibation of RET kinase",
    "polaris/drewry2017-pkis2-subset-v2/CLS_LOK": "inhibation of LOK kinase",
    "polaris/drewry2017-pkis2-subset-v2/CLS_SLK": "inhibation of SLK kinase",
    ### Biogen ADME-FANG
    "biogen/adme-fang-solu-reg-v1": "log-solubility at pH6.8 (log \u03bcg/mL)",
    "biogen/adme-fang-rppb-reg-v1": "rat plasma protein binding (log-percent unbound to plasma protein)",
    "biogen/adme-fang-hppb-reg-v1": "human plasma protein binding (log-percent unbound to plasma protein)",
    "biogen/adme-fang-perm-reg-v1": "log-MDR1 MDCK efflux ratio",
    "biogen/adme-fang-hclint-reg-v1": "human log-liver microsomal stability (log mL/min/kg)",
    "biogen/adme-fang-rclint-reg-v1": "rat log-liver microsomal stability (log mL/min/kg)",
    ### TDCommons
    "tdcommons/pgp-broccatelli": "inhibition of the P-glycoprotein",
    "tdcommons/vdss-lombardo": "log-volume of distribution at steady state (log L/kg)",
    "tdcommons/bbb-martins": "ablity to penetrate the blood-brain barrier",
    "tdcommons/caco2-wang": "Caco-2 cell effective log-permeability (log cm/s)",
    "tdcommons/dili": "ability to induce liver injuries",
    "tdcommons/herg": "blocker of hERG",
    "tdcommons/ames": "mutagenicity",
    "tdcommons/half-life-obach": "log-half-life (log hr) in human body",
    "tdcommons/lipophilicity-astrazeneca": "lipophilicity (log-ratio)",
    "tdcommons/clearance-hepatocyte-az": "log-drug clearance, hepatocyte assay (log \u03bcL/min/10^6 cells)",
    "tdcommons/clearance-microsome-az": "log-drug clearance, microsome assay (log mL/min/g)",
    "tdcommons/ld50-zhu": "LD50 toxicity (log kg/mol)",
    "tdcommons/cyp2c9-substrate-carbonmangels": "being a substrate of CYP2C9",
    "tdcommons/cyp2d6-substrate-carbonmangels": "being a substrate of CYP2D6",
    "tdcommons/cyp3a4-substrate-carbonmangels": "being a substrate of CYP3A4",
    "tdcommons/solubility-aqsoldb": "log-solubility (log mol/L)",
}

# %%
jinja_template = """Given a molecular SMILES, you are asked to predict its following property: {{ short_prop }}.
Provide your predicted value in a box (i.e \\boxed{ {%- if objectives[0] == "classification" %}yes or no{%- elif objectives[0] == "regression" %}property value{% endif -%}}) in your final answer.

Molecule to analyze: {{ smiles[0] }}.
"""

pg = PromptGenerator(jinja_template, "data/molgendata")

# %%
from copy import copy

for split in ["train", "eval"]:
    prompt_dataset = []
    n_lines = 0
    for path in MOLPROP_DATA_PATH.rglob(f"*/{split}.jsonl"):
        with open(path) as f:
            n_lines += sum(1 for _ in f)

    pbar =tqdm(total=n_lines, desc=f"Generating {split} prompts")
    for path in MOLPROP_DATA_PATH.rglob(f"*/{split}.jsonl"):
        data = read_jsonl(path)
        short_prop = TO_SHORTNAME[
            str(path).replace(f"/{split}.jsonl", "").replace("data/polaris/", "")
        ]
        pbar.set_description(f"Generating prompts for {short_prop}")
        for item in data:
            metadata = copy(item.conversations[0].meta)
            assert item.conversations[0].messages[0].role == "system"
            assert item.conversations[0].messages[1].role == "user"
            del item.conversations[0].messages[0]

            metadata["short_prop"] = short_prop
            new_content = pg(metadata)

            item.conversations[0].messages[0].content = new_content

            item.identifier = item.identifier.replace("train", split)
            item.conversations[0].identifier = item.conversations[0].identifier.replace("train", split)

            prompt_dataset.append(item)
            pbar.update(1)
        print(
            prompt_dataset[-1].conversations[0].messages[0].content
        )
        print("===="*30)
        print("===="*30)
    pbar.close()

    write_path = Path(f"data/property_prediction/{split}_prompts_boxed.jsonl")
    write_path.parent.mkdir(parents=True, exist_ok=True)
    write_jsonl(write_path, prompt_dataset)
# Out:
# Generating train prompts:   0%|          | 0/54734 [00:00<?, ?it/s]
# Given a molecular SMILES, you are asked to predict its following property: log-half-life (log hr) in human body.
# Provide your predicted value in a box (i.e \boxed{property value}) in your final answer.
#
# Molecule to analyze: CCOC(=O)c1ncn2c1CN(C)C(=O)c1cc(F)ccc1-2.
# ========================================================================================================================
# ========================================================================================================================
# Given a molecular SMILES, you are asked to predict its following property: log-drug clearance, hepatocyte assay (log μL/min/10^6 cells).
# Provide your predicted value in a box (i.e \boxed{property value}) in your final answer.
#
# Molecule to analyze: Cc1ccc(S(=O)(=O)Nc2c(C(=O)N[C@@H](C)C(C)(C)C)c(C)nn2C2CCN(C)CC2)cc1.
# ========================================================================================================================
# ========================================================================================================================
# Given a molecular SMILES, you are asked to predict its following property: being a substrate of CYP2C9.
# Provide your predicted value in a box (i.e \boxed{yes or no}) in your final answer.
#
# Molecule to analyze: COc1cc(Br)c2oc(C3CCNCC3)cc2c1.
# ========================================================================================================================
# ========================================================================================================================
# Given a molecular SMILES, you are asked to predict its following property: being a substrate of CYP3A4.
# Provide your predicted value in a box (i.e \boxed{yes or no}) in your final answer.
#
# Molecule to analyze: CNC(=O)c1cccc(NCC(=O)NCCc2ccc(OC)c(OC)c2)c1.
# ========================================================================================================================
# ========================================================================================================================
# Given a molecular SMILES, you are asked to predict its following property: LD50 toxicity (log kg/mol).
# Provide your predicted value in a box (i.e \boxed{property value}) in your final answer.
#
# Molecule to analyze: CC(C)N(Sc1nc2ccccc2s1)C(C)C.
# ========================================================================================================================
# ========================================================================================================================
# Given a molecular SMILES, you are asked to predict its following property: lipophilicity (log-ratio).
# Provide your predicted value in a box (i.e \boxed{property value}) in your final answer.
#
# Molecule to analyze: CC(C)Oc1cc(Nc2nc3c(cc2F)ncn3[C@@H](CO)c2ccc(F)cn2)n[nH]1.
# ========================================================================================================================
# ========================================================================================================================
# Given a molecular SMILES, you are asked to predict its following property: log-volume of distribution at steady state (log L/kg).
# Provide your predicted value in a box (i.e \boxed{property value}) in your final answer.
#
# Molecule to analyze: CN/C(=N\CCSCc1nc[nH]c1C)NC#N.
# ========================================================================================================================
# ========================================================================================================================
# Given a molecular SMILES, you are asked to predict its following property: log-drug clearance, microsome assay (log mL/min/g).
# Provide your predicted value in a box (i.e \boxed{property value}) in your final answer.
#
# Molecule to analyze: CN(C)CC(O)COc1ccc(Nc2ncc(Cl)c(Nc3ccccc3)n2)cc1.
# ========================================================================================================================
# ========================================================================================================================
# Given a molecular SMILES, you are asked to predict its following property: log-solubility (log mol/L).
# Provide your predicted value in a box (i.e \boxed{property value}) in your final answer.
#
# Molecule to analyze: NC(=O)NC(=O)C=CC(=O)O.
# ========================================================================================================================
# ========================================================================================================================
# Given a molecular SMILES, you are asked to predict its following property: mutagenicity.
# Provide your predicted value in a box (i.e \boxed{yes or no}) in your final answer.
#
# Molecule to analyze: Cc1cccc2c1cc1ccc3cccc4ccc2c1c34.
# ========================================================================================================================
# ========================================================================================================================
# Given a molecular SMILES, you are asked to predict its following property: ablity to penetrate the blood-brain barrier.
# Provide your predicted value in a box (i.e \boxed{yes or no}) in your final answer.
#
# Molecule to analyze: CC(CN(C)C)CN1c2ccccc2S(=O)(=O)c2ccccc21.
# ========================================================================================================================
# ========================================================================================================================
# Given a molecular SMILES, you are asked to predict its following property: Caco-2 cell effective log-permeability (log cm/s).
# Provide your predicted value in a box (i.e \boxed{property value}) in your final answer.
#
# Molecule to analyze: CCOC(=O)c1ccc(O)cc1.
# ========================================================================================================================
# ========================================================================================================================
# Given a molecular SMILES, you are asked to predict its following property: ability to induce liver injuries.
# Provide your predicted value in a box (i.e \boxed{yes or no}) in your final answer.
#
# Molecule to analyze: CO[Si](C)(C)O[Si](C)(C)C.O=[Si]=O.
# ========================================================================================================================
# ========================================================================================================================
# Given a molecular SMILES, you are asked to predict its following property: blocker of hERG.
# Provide your predicted value in a box (i.e \boxed{yes or no}) in your final answer.
#
# Molecule to analyze: CCCCCCC[N+](CC)(CC)CCCCc1ccc(Cl)cc1.
# ========================================================================================================================
# ========================================================================================================================
# Given a molecular SMILES, you are asked to predict its following property: inhibition of the P-glycoprotein.
# Provide your predicted value in a box (i.e \boxed{yes or no}) in your final answer.
#
# Molecule to analyze: COc1cc2c(cc1OC)CN(CCc1ccc(NC(=O)c3ccccc3NC(=O)c3cccs3)cc1)CC2.
# ========================================================================================================================
# ========================================================================================================================
# Given a molecular SMILES, you are asked to predict its following property: being a substrate of CYP2D6.
# Provide your predicted value in a box (i.e \boxed{yes or no}) in your final answer.
#
# Molecule to analyze: CCCc1nc2c(C)cc(-c3nc4ccccc4n3C)cc2n1Cc1ccc(-c2ccccc2C(=O)O)cc1.
# ========================================================================================================================
# ========================================================================================================================
# Given a molecular SMILES, you are asked to predict its following property: human plasma protein binding (log-percent unbound to plasma protein).
# Provide your predicted value in a box (i.e \boxed{property value}) in your final answer.
#
# Molecule to analyze: CC(=O)N1CCN(c2nc(C(F)(F)F)nc3sc(C)c(C)c23)CC1.
# ========================================================================================================================
# ========================================================================================================================
# Given a molecular SMILES, you are asked to predict its following property: human log-liver microsomal stability (log mL/min/kg).
# Provide your predicted value in a box (i.e \boxed{property value}) in your final answer.
#
# Molecule to analyze: N#Cc1ccc(C(=O)Nn2cnnc2)cc1.
# ========================================================================================================================
# ========================================================================================================================
# Given a molecular SMILES, you are asked to predict its following property: log-solubility at pH6.8 (log μg/mL).
# Provide your predicted value in a box (i.e \boxed{property value}) in your final answer.
#
# Molecule to analyze: Cc1ccn(-c2ccc3[nH]c4c(c3c2)CCCC4=O)n1.
# ========================================================================================================================
# ========================================================================================================================
# Given a molecular SMILES, you are asked to predict its following property: rat log-liver microsomal stability (log mL/min/kg).
# Provide your predicted value in a box (i.e \boxed{property value}) in your final answer.
#
# Molecule to analyze: COc1ccc(C2(NCc3cnn(-c4ccccc4)c3)CCCC2)cc1.
# ========================================================================================================================
# ========================================================================================================================
# Given a molecular SMILES, you are asked to predict its following property: log-MDR1 MDCK efflux ratio.
# Provide your predicted value in a box (i.e \boxed{property value}) in your final answer.
#
# Molecule to analyze: Fc1ccc(Nc2nc(N3CCCCC3)c3nccnc3n2)cc1.
# ========================================================================================================================
# ========================================================================================================================
# Given a molecular SMILES, you are asked to predict its following property: rat plasma protein binding (log-percent unbound to plasma protein).
# Provide your predicted value in a box (i.e \boxed{property value}) in your final answer.
#
# Molecule to analyze: O=C1NCCN(C(=O)c2ccc3nccn3c2)C1c1ccccc1C(F)(F)F.
# ========================================================================================================================
# ========================================================================================================================
# Given a molecular SMILES, you are asked to predict its following property: log-inactivation rate constant of CYP3A4.
# Provide your predicted value in a box (i.e \boxed{property value}) in your final answer.
#
# Molecule to analyze: CN(CC(=O)N1CCCC(c2ccccc2)C1CN1CCOCC1)c1ccc(Cl)c(Cl)c1.
# ========================================================================================================================
# ========================================================================================================================
# Given a molecular SMILES, you are asked to predict its following property: octan-1-ol/water (pH7.4) distribution coefficent.
# Provide your predicted value in a box (i.e \boxed{property value}) in your final answer.
#
# Molecule to analyze: Cc1nc(CS(=O)(=O)c2ccccc2)cc(N2CCOCC2)n1.
# ========================================================================================================================
# ========================================================================================================================
# Given a molecular SMILES, you are asked to predict its following property: plasma protein binding (log-percent unbound to plasma protein).
# Provide your predicted value in a box (i.e \boxed{property value}) in your final answer.
#
# Molecule to analyze: C[C@@H](NC1=CC(=O)NCC1)c1ccc(Nc2ncc3cc(-c4ccncc4)ccc3n2)cc1.
# ========================================================================================================================
# ========================================================================================================================
# Given a molecular SMILES, you are asked to predict its following property: inhibation of LOK kinase.
# Provide your predicted value in a box (i.e \boxed{yes or no}) in your final answer.
#
# Molecule to analyze: NC(=O)c1cc(-c2ccccc2)cc2c(C3CCNCC3)c[nH]c12.
# ========================================================================================================================
# ========================================================================================================================
# Given a molecular SMILES, you are asked to predict its following property: inhibation of KIT kinase.
# Provide your predicted value in a box (i.e \boxed{yes or no}) in your final answer.
#
# Molecule to analyze: Cn1ccc2ncnc(Oc3ccc(NC(=O)Nc4ccccc4)cc3)c21.
# ========================================================================================================================
# ========================================================================================================================
# Given a molecular SMILES, you are asked to predict its following property: inhibation of EGFR kinase.
# Provide your predicted value in a box (i.e \boxed{yes or no}) in your final answer.
#
# Molecule to analyze: COC(=O)c1cccc(NC(=O)NC2CCN(c3ccnc(Nc4ccc(F)cc4)n3)C2)c1.
# ========================================================================================================================
# ========================================================================================================================
# Given a molecular SMILES, you are asked to predict its following property: inhibation of RET kinase.
# Provide your predicted value in a box (i.e \boxed{yes or no}) in your final answer.
#
# Molecule to analyze: COc1cc2ncn(-c3cc(OCCCc4ccccc4)c(C(N)=O)s3)c2cc1OC.
# ========================================================================================================================
# ========================================================================================================================
# Given a molecular SMILES, you are asked to predict its following property: inhibation of SLK kinase.
# Provide your predicted value in a box (i.e \boxed{yes or no}) in your final answer.
#
# Molecule to analyze: O=C(Nc1cccc(-c2nn3ccccc3c2-c2ccnc(Nc3cccc(C(F)(F)F)c3)n2)c1)c1c(F)cccc1F.
# ========================================================================================================================
# ========================================================================================================================
# Given a molecular SMILES, you are asked to predict its following property: SARS-CoV-2 main protease inhibition potency (pIC50).
# Provide your predicted value in a box (i.e \boxed{property value}) in your final answer.
#
# Molecule to analyze: O=C(CC1=CN=CC2=CC=CC=C12)N1C[C@H](F)C[C@H]1C1=CC=CC(F)=C1.
# ========================================================================================================================
# ========================================================================================================================
# Given a molecular SMILES, you are asked to predict its following property: MERS-CoV main protease inhibition potency (pIC50).
# Provide your predicted value in a box (i.e \boxed{property value}) in your final answer.
#
# Molecule to analyze: O=C(CC1=CN=CC2=CC=CC=C12)N1CCCCC[C@H]1CC1=CC=CS1.
# ========================================================================================================================
# ========================================================================================================================
# Generating eval prompts:   0%|          | 0/13694 [00:00<?, ?it/s]
# Given a molecular SMILES, you are asked to predict its following property: log-half-life (log hr) in human body.
# Provide your predicted value in a box (i.e \boxed{property value}) in your final answer.
#
# Molecule to analyze: CC#CCC(C)[C@H](O)/C=C/[C@@H]1[C@H]2C/C(=C/CCCC(=O)O)C[C@H]2C[C@H]1O.
# ========================================================================================================================
# ========================================================================================================================
# Given a molecular SMILES, you are asked to predict its following property: log-drug clearance, hepatocyte assay (log μL/min/10^6 cells).
# Provide your predicted value in a box (i.e \boxed{property value}) in your final answer.
#
# Molecule to analyze: CCn1c(SCC(=O)Nc2cc(C)on2)nnc1-c1cccnc1.
# ========================================================================================================================
# ========================================================================================================================
# Given a molecular SMILES, you are asked to predict its following property: being a substrate of CYP2C9.
# Provide your predicted value in a box (i.e \boxed{yes or no}) in your final answer.
#
# Molecule to analyze: COc1ccc(CN(CCN(C)C)c2ccccn2)cc1.
# ========================================================================================================================
# ========================================================================================================================
# Given a molecular SMILES, you are asked to predict its following property: being a substrate of CYP3A4.
# Provide your predicted value in a box (i.e \boxed{yes or no}) in your final answer.
#
# Molecule to analyze: C[C@@H](c1cc2ccccc2s1)N(O)C(N)=O.
# ========================================================================================================================
# ========================================================================================================================
# Given a molecular SMILES, you are asked to predict its following property: LD50 toxicity (log kg/mol).
# Provide your predicted value in a box (i.e \boxed{property value}) in your final answer.
#
# Molecule to analyze: CC1(C2CCC3(C)OC3C2)CO1.
# ========================================================================================================================
# ========================================================================================================================
# Given a molecular SMILES, you are asked to predict its following property: lipophilicity (log-ratio).
# Provide your predicted value in a box (i.e \boxed{property value}) in your final answer.
#
# Molecule to analyze: Cc1ccc(-c2cc(C(F)(F)F)nn2-c2ccc(S(N)(=O)=O)cc2)cc1.
# ========================================================================================================================
# ========================================================================================================================
# Given a molecular SMILES, you are asked to predict its following property: log-volume of distribution at steady state (log L/kg).
# Provide your predicted value in a box (i.e \boxed{property value}) in your final answer.
#
# Molecule to analyze: CCC(C)C(C(CC(=O)N1CCCC1C(OC)C(C)C(=O)NCCc1ccccc1)OC)N(C)C(=O)C(NC(=O)C(C(C)C)N(C)C)C(C)C.
# ========================================================================================================================
# ========================================================================================================================
# Given a molecular SMILES, you are asked to predict its following property: log-drug clearance, microsome assay (log mL/min/g).
# Provide your predicted value in a box (i.e \boxed{property value}) in your final answer.
#
# Molecule to analyze: CC[C@@H](Nc1c(Nc2cccc(C(=O)N(C)C)c2O)c(=O)c1=O)c1ccccc1.
# ========================================================================================================================
# ========================================================================================================================
# Given a molecular SMILES, you are asked to predict its following property: log-solubility (log mol/L).
# Provide your predicted value in a box (i.e \boxed{property value}) in your final answer.
#
# Molecule to analyze: O=C1OCCCN1/N=C/c1ccc([N+](=O)[O-])o1.
# ========================================================================================================================
# ========================================================================================================================
# Given a molecular SMILES, you are asked to predict its following property: mutagenicity.
# Provide your predicted value in a box (i.e \boxed{yes or no}) in your final answer.
#
# Molecule to analyze: COC(=O)c1cccc2oc3c4c(cc(OC)c3c(=O)c12)OC1OC=CC41.
# ========================================================================================================================
# ========================================================================================================================
# Given a molecular SMILES, you are asked to predict its following property: ablity to penetrate the blood-brain barrier.
# Provide your predicted value in a box (i.e \boxed{yes or no}) in your final answer.
#
# Molecule to analyze: CC1(C)CN(CCN2CCN(c3cccc(Cl)c3)C2=O)C1.
# ========================================================================================================================
# ========================================================================================================================
# Given a molecular SMILES, you are asked to predict its following property: Caco-2 cell effective log-permeability (log cm/s).
# Provide your predicted value in a box (i.e \boxed{property value}) in your final answer.
#
# Molecule to analyze: Cc1ccnc2nc(Cc3nc4cc(C(=N)N)ccc4[nH]3)[nH]c12.
# ========================================================================================================================
# ========================================================================================================================
# Given a molecular SMILES, you are asked to predict its following property: ability to induce liver injuries.
# Provide your predicted value in a box (i.e \boxed{yes or no}) in your final answer.
#
# Molecule to analyze: CCC(=C(c1ccccc1)c1ccc(OCCN(C)C)cc1)c1ccccc1.
# ========================================================================================================================
# ========================================================================================================================
# Given a molecular SMILES, you are asked to predict its following property: blocker of hERG.
# Provide your predicted value in a box (i.e \boxed{yes or no}) in your final answer.
#
# Molecule to analyze: CCC[NH2+]CC(O)COc1ccccc1C(=O)CCc1ccccc1.
# ========================================================================================================================
# ========================================================================================================================
# Given a molecular SMILES, you are asked to predict its following property: inhibition of the P-glycoprotein.
# Provide your predicted value in a box (i.e \boxed{yes or no}) in your final answer.
#
# Molecule to analyze: Cc1ccccc1OC[C@H](O)CNCCn1cc(C)c(=O)[nH]c1=O.
# ========================================================================================================================
# ========================================================================================================================
# Given a molecular SMILES, you are asked to predict its following property: being a substrate of CYP2D6.
# Provide your predicted value in a box (i.e \boxed{yes or no}) in your final answer.
#
# Molecule to analyze: CCCC(=O)O[C@H]1[C@H](C)O[C@@H](O[C@@H]2[C@@H](C)O[C@@H](O[C@@H]3[C@@H](OC)[C@H](O)CC(=O)O[C@H](C)CC=CC=C[C@H](O)[C@H](C)C[C@@H]3CC=O)[C@H](O)[C@H]2N(C)C)C[C@@]1(C)OC(=O)CC.
# ========================================================================================================================
# ========================================================================================================================
# Given a molecular SMILES, you are asked to predict its following property: human plasma protein binding (log-percent unbound to plasma protein).
# Provide your predicted value in a box (i.e \boxed{property value}) in your final answer.
#
# Molecule to analyze: Cc1ccc(OCC2(O)CCN(CC3(O)CCN(c4ccccc4C)CC3)CC2)cc1.
# ========================================================================================================================
# ========================================================================================================================
# Given a molecular SMILES, you are asked to predict its following property: human log-liver microsomal stability (log mL/min/kg).
# Provide your predicted value in a box (i.e \boxed{property value}) in your final answer.
#
# Molecule to analyze: c1cncc(-c2nnc3n2[C@H]2CN(Cc4cccs4)C[C@H]2CC3)c1.
# ========================================================================================================================
# ========================================================================================================================
# Given a molecular SMILES, you are asked to predict its following property: log-solubility at pH6.8 (log μg/mL).
# Provide your predicted value in a box (i.e \boxed{property value}) in your final answer.
#
# Molecule to analyze: c1nc(NC2CCN(C3CC3)CC2)c2sccc2n1.
# ========================================================================================================================
# ========================================================================================================================
# Given a molecular SMILES, you are asked to predict its following property: rat log-liver microsomal stability (log mL/min/kg).
# Provide your predicted value in a box (i.e \boxed{property value}) in your final answer.
#
# Molecule to analyze: c1cncc(-c2nnc3n2[C@H]2CN(Cc4cccs4)C[C@H]2CC3)c1.
# ========================================================================================================================
# ========================================================================================================================
# Given a molecular SMILES, you are asked to predict its following property: log-MDR1 MDCK efflux ratio.
# Provide your predicted value in a box (i.e \boxed{property value}) in your final answer.
#
# Molecule to analyze: c1sc(NCC2CCCO2)nc1C12CC3CC(CC(C3)C1)C2.
# ========================================================================================================================
# ========================================================================================================================
# Given a molecular SMILES, you are asked to predict its following property: rat plasma protein binding (log-percent unbound to plasma protein).
# Provide your predicted value in a box (i.e \boxed{property value}) in your final answer.
#
# Molecule to analyze: COc1ccccc1-c1cc(NC(=O)c2cccc(N3CCNC3=O)c2)[nH]n1.
# ========================================================================================================================
# ========================================================================================================================
# Given a molecular SMILES, you are asked to predict its following property: log-inactivation rate constant of CYP3A4.
# Provide your predicted value in a box (i.e \boxed{property value}) in your final answer.
#
# Molecule to analyze: Cc1cn([C@H]2C[C@H](N=[N+]=[N-])[C@@H](CO)O2)c(=O)[nH]c1=O.
# ========================================================================================================================
# ========================================================================================================================
# Given a molecular SMILES, you are asked to predict its following property: octan-1-ol/water (pH7.4) distribution coefficent.
# Provide your predicted value in a box (i.e \boxed{property value}) in your final answer.
#
# Molecule to analyze: c1cncc(Nc2ncnc3ccccc23)c1.
# ========================================================================================================================
# ========================================================================================================================
# Given a molecular SMILES, you are asked to predict its following property: plasma protein binding (log-percent unbound to plasma protein).
# Provide your predicted value in a box (i.e \boxed{property value}) in your final answer.
#
# Molecule to analyze: c1ccc([C@H]([C@@H](c2ccccc2)N2CCCCC2)N2CCCCC2)cc1.
# ========================================================================================================================
# ========================================================================================================================
# Given a molecular SMILES, you are asked to predict its following property: inhibation of LOK kinase.
# Provide your predicted value in a box (i.e \boxed{yes or no}) in your final answer.
#
# Molecule to analyze: c1ccc(-c2cc(-c3c[nH]nc3-c3ccccn3)ccn2)cc1.
# ========================================================================================================================
# ========================================================================================================================
# Given a molecular SMILES, you are asked to predict its following property: inhibation of KIT kinase.
# Provide your predicted value in a box (i.e \boxed{yes or no}) in your final answer.
#
# Molecule to analyze: O=C(Nc1n[nH]c2nc(-c3cccc(O)c3)ccc12)C1CC1.
# ========================================================================================================================
# ========================================================================================================================
# Given a molecular SMILES, you are asked to predict its following property: inhibation of EGFR kinase.
# Provide your predicted value in a box (i.e \boxed{yes or no}) in your final answer.
#
# Molecule to analyze: c1ccc(-c2ccnc3[nH]ccc23)cc1.
# ========================================================================================================================
# ========================================================================================================================
# Given a molecular SMILES, you are asked to predict its following property: inhibation of RET kinase.
# Provide your predicted value in a box (i.e \boxed{yes or no}) in your final answer.
#
# Molecule to analyze: c1ccc(-c2ccnc3[nH]ccc23)cc1.
# ========================================================================================================================
# ========================================================================================================================
# Given a molecular SMILES, you are asked to predict its following property: inhibation of SLK kinase.
# Provide your predicted value in a box (i.e \boxed{yes or no}) in your final answer.
#
# Molecule to analyze: c1ccc(-c2cc(-c3c[nH]nc3-c3ccccn3)ccn2)cc1.
# ========================================================================================================================
# ========================================================================================================================
# Given a molecular SMILES, you are asked to predict its following property: SARS-CoV-2 main protease inhibition potency (pIC50).
# Provide your predicted value in a box (i.e \boxed{property value}) in your final answer.
#
# Molecule to analyze: O=C(CC1=CN=CC2=CC=CC=C12)N1CCCC[C@H]1[C@H]1CCCO1.
# ========================================================================================================================
# ========================================================================================================================
# Given a molecular SMILES, you are asked to predict its following property: MERS-CoV main protease inhibition potency (pIC50).
# Provide your predicted value in a box (i.e \boxed{property value}) in your final answer.
#
# Molecule to analyze: COC1=CC=CC=C1[C@H]1C[C@H](C)CCN1C(=O)CC1=CN=CC2=CC=CC=C12.
# ========================================================================================================================
# ========================================================================================================================

# %% [markdown]
# # Molecular Reaction - Prompt Generation

# %%
from mol_gen_docking.dataset.scripts.reaction_task.utils import full_jinja

pg = PromptGenerator(full_jinja, "data/molgendata")
path_dir =  Path("data/synthesis")
out_dir = Path("data/synthesis_tasks")
out_dir.mkdir(parents=True, exist_ok=True)
full_dataset = []

i = 0

for path in path_dir.rglob("train_prompts_*.jsonl"):
    try:
        data = read_jsonl(path)
    except Exception as e:
        print(f"Error reading {path}: {e}")
        continue
    obj_text = {}
    for item in tqdm(data, desc=path.name):
        metadata = item.conversations[0].meta
        new_content = pg(metadata)

        item.identifier = item.identifier + f"_{i}"
        item.conversations[0].identifier = item.conversations[0].identifier + f"_{i}"

        item.conversations[0].messages[0].content = new_content
        item.conversations[0].meta = metadata
        if metadata["objectives"][0] not in obj_text:
            obj_text[metadata["objectives"][0]] = new_content
    i+=1
    full_dataset += data

write_path = out_dir / "train_prompts_unclean_json.jsonl"
write_jsonl(write_path, full_dataset)

# %%
from mol_gen_docking.data.reactions.utils import PROMPT_TASKS

for k in PROMPT_TASKS[1:3]:
    v = obj_text.get(k, "No prompt generated for this objective")
    print("Objective:", k)
    print(v)
    print("====="*20)

# %%
pg = PromptGenerator(full_jinja, "data/molgendata")
in_dir =  Path("data/synthesis")
out_dir = Path("data/synthesis_tasks/eval_prompts")
out_dir.mkdir(parents=True, exist_ok=True)

for path in in_dir.rglob("*eval*.jsonl"):
    data = read_jsonl(path)
    obj_text = {}
    for item in tqdm(data):
        metadata = item.conversations[0].meta
        try:
            new_content = pg(metadata)
        except Exception as e:
            print(metadata)
            raise e

        item.conversations[0].messages[0].content = new_content
        item.conversations[0].meta = metadata
        if metadata["objectives"][0] not in obj_text:
            obj_text[metadata["objectives"][0]] = new_content

    write_path = out_dir / path.name
    write_jsonl(write_path, data)
